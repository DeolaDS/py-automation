# %%
import sys
import requests

# %%
def getWeather(city):
    response = requests.get(f'https://wttr.in/{city.replace(" ", "+")}')
    print(response.text)

# %%
getWeather('Dubai')
# Out:
# Weather report: Dubai
#
#       \   /     Sunny
#        .-.      +30(33) °C
#     ― (   ) ―   ↑ 13 km/h
#        `-’      7 km
#       /   \     0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 10 Jun ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │     \   /     Sunny          │     \   /     Clear          │
# │      .-.      +35(39) °C     │      .-.      +39(53) °C     │      .-.      +34(44) °C     │      .-.      +30(38) °C     │
# │   ― (   ) ―   ↗ 23-33 km/h   │   ― (   ) ―   ↗ 25-28 km/h   │   ― (   ) ―   → 15-19 km/h   │   ― (   ) ―   ↗ 15-28 km/h   │
# ...
